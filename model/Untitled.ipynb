# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
msft.insider_transactions
msft.insider_purchases
msft.insider_roster_holders

# show recommendations
msft.recommendations
msft.recommendations_summary
msft.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
# opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
# Out:
# [{'uuid': '4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b',
#   'title': 'Magnificent Seven Stocks: Nvidia Stock Slides; Amazon Rallies On Earnings',
#   'publisher': "Investor's Business Daily",
#   'link': 'https://finance.yahoo.com/m/4205eaa9-f620-3a0b-a81a-0e82c7c9fd0b/magnificent-seven-stocks%3A.html',
#   'providerPublishTime': 1714570662,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/IVY_jviTG_ue49k31izfew--~B/aD02MDA7dz0xMDY1O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 1065,
#      'height': 600,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/EDUpiEmpjj.CUhr9H67TBQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/f287385a5f84c1d1e13191d4ae92d9fb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA', 'AAPL', 'TSLA', 'META', 'MSFT']},
#  {'uuid': '9e3db6ec-b884-39a9-8793-dee15b70b1fa',
#   'title': 'Microsoft Strikes Major Renewable Power Deal With Brookfield',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/microsoft-strikes-renewable-power-deal-115226797.html',
#   'providerPublishTime': 1714566622,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/I4RPufHFxn1GjF86R11OUg--~B/aD0xMzMzO3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_markets_842/b9f52389f37b6b793a7fefefd7ad6480',
#      'width': 2000,
#      'height': 1333,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/CWgJFAweQr8ezYjDMQttuA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/b9f52389f37b6b793a7fefefd7ad6480',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'BAM']},
#  {'uuid': '18221053-a7d7-3223-bb33-54675ff37d09',
#   'title': 'AI Hardware Stocks Get Pummeled Even as Big Tech Keeps Spending',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/ai-hardware-stocks-pummeled-even-120751254.html',
#   'providerPublishTime': 1714565271,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/.wup77RacpbRcAEl3uIaLg--~B/aD02NzU7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/c0071b749f4f9ff98be95b1f382c387b',
#      'width': 1200,
#      'height': 675,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/7DLRJQFSRsaU_TNilYzWiA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/c0071b749f4f9ff98be95b1f382c387b',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['AMD', 'SMCI', 'NVDA', 'MSFT']},
#  {'uuid': '47a288ee-afec-387a-87d8-0da6d2f7beb1',
#   'title': 'Microsoft Strikes Deal With Brookfield to Back $10 Billion in Renewable Energy Projects',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/microsoft-strikes-deal-brookfield-back-120328727.html',
#   'providerPublishTime': 1714565008,
#   'type': 'STORY',
#   'relatedTickers': ['MSFT', 'BAM']},
#  {'uuid': '29ea4532-4095-3774-8e66-590c9406f8a5',
#   'title': "Microsoft's Earnings Results Show It's Delivering on Its Artificial Intelligence (AI) Promise. But Is the Stock a Buy After Recent Gains?",
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/29ea4532-4095-3774-8e66-590c9406f8a5/microsoft%27s-earnings-results.html',
#   'providerPublishTime': 1714563000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/mieP_cq0jm2TZTlg27gx0w--~B/aD03OTk7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/7e3b87fa4a29f33bf682710b44fbd4ed',
#      'width': 1400,
#      'height': 799,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/FHbz2j4ONduwl3OKItU0_A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/7e3b87fa4a29f33bf682710b44fbd4ed',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '10af0eec-55f5-3678-9a7a-ab861c29e367',
#   'title': '2 Dominant AI Companies to Buy and 1 to Sell',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/10af0eec-55f5-3678-9a7a-ab861c29e367/2-dominant-ai-companies-to.html',
#   'providerPublishTime': 1714563000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/zfKu0piDYQDJhTYC88xuWg--~B/aD0xMjk5O3c9MjMwOTthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/a3379cea6d96317bbc23aa0bf214a236',
#      'width': 2309,
#      'height': 1299,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/8l1jzBj3umRKWMVRxdvWhw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/a3379cea6d96317bbc23aa0bf214a236',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT', 'GOOG']},
#  {'uuid': '30612f3c-29e0-3fd8-a6f2-e2491010c3b1',
#   'title': 'Microsoft Third Quarter 2024 Earnings: Beats Expectations',
#   'publisher': 'Simply Wall St.',
#   'link': 'https://finance.yahoo.com/news/microsoft-third-quarter-2024-earnings-111550177.html',
#   'providerPublishTime': 1714562150,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/5Vpve0Pc2F3m_L3fs2p_dQ--~B/aD02MzY7dz05NDU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/78a8c60a6283aea0450523395306d38c',
#      'width': 945,
#      'height': 636,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/NamfX5LEtyScIu4YmRG2hg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/78a8c60a6283aea0450523395306d38c',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['MSFT']},
#  {'uuid': '694db2ad-d3be-37e8-a322-ec1609c419df',
#   'title': 'Brookfield Up 1% in U.S. Premarket After Renewable Power Agreement With Microsoft',
#   'publisher': 'MT Newswires',
#   'link': 'https://finance.yahoo.com/news/brookfield-1-u-premarket-renewable-105444457.html',
#   'providerPublishTime': 1714560884,
#   'type': 'STORY',
#   'relatedTickers': ['MSFT', 'BAM', 'BEP']}]
